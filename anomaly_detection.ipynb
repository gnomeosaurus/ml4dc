# %%
# import setGPU
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

from sklearn.utils import shuffle
import h5py
# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42
LABELS = ["Normal", "Anomalous"]
# Out:
# Using TensorFlow backend.

# %%
#Choose where to load the files from
b_h5 = '/eos/cms/store/user/fsiroky/hdf5_data/'
# b_h5 = '/mnt/hdf5test/'
# b_h5   = '/home/test_local/'

pds  = {1: 'BTagCSV', 2: 'BTagMu', 3: 'Charmonium', 4:'DisplacedJet', 5: 'DoubleEG',
        6: 'DoubleMuon', 7: 'DoubleMuonLowMass',
       # 8: 'FSQJets', 9: 'HighMultiplicityEOF', #NOT ENOUGH DATA, NOTEBOOK FAILES
        10: 'HTMHT', 11: 'JetHT', 12: 'MET',
       # 13: 'MinimumBias', #NOT ENOUGH DATA
        14: 'MuonEG', 15: 'MuOnia',
       # 16: 'NoBPTX',
        17: 'SingleElectron', 18: 'SingleMuon', 19: 'SinglePhoton', 20: 'Tau', 21: 'ZeroBias'
}

#Choose which PD to load
nbr = 11

bg_files  = [b_h5+pds[nbr]+'_C_background.h5',b_h5+pds[nbr]+'_D_background.h5', b_h5+pds[nbr]+'_E_background.h5',
             b_h5+pds[nbr]+'_F_background.h5', b_h5+pds[nbr]+'_G_background.h5', b_h5+pds[nbr]+'_H_background.h5']

bg_jets   = [pds[nbr]+"_C_background", pds[nbr]+"_D_background", pds[nbr]+"_E_background",
             pds[nbr]+"_F_background", pds[nbr]+"_G_background", pds[nbr]+"_H_background"]

sig_files = [b_h5+pds[nbr]+'_C_signal.h5',b_h5+pds[nbr]+'_D_signal.h5', b_h5+pds[nbr]+'_E_signal.h5',
             b_h5+pds[nbr]+'_F_signal.h5', b_h5+pds[nbr]+'_G_signal.h5', b_h5+pds[nbr]+'_H_signal.h5']

sig_jets  = [pds[nbr]+"_C_signal", pds[nbr]+"_D_signal", pds[nbr]+"_E_signal",
             pds[nbr]+"_F_signal", pds[nbr]+"_G_signal", pds[nbr]+"_H_signal"]

      
def get_jets(bg_files, bg_jets, sig_files, sig_jets):
    good_jets = np.empty([0,2802])
    bad_jets  = np.empty([0,2802])
                   # Control which time intervals files per PD to load with range in the for loop
    for i in range(0,len(bg_files)-5):
        try:
            bg_jetfile  = h5py.File(bg_files[i],'r')
            bg_jet      = bg_jetfile[bg_jets[i]][:]
            sig_jetfile = h5py.File(sig_files[i],'r')
            sig_jet     = sig_jetfile[sig_jets[i]][:]

            bad_jets    = np.concatenate((bad_jets, bg_jet), axis=0)
            good_jets = np.concatenate((good_jets, sig_jet), axis=0)
            print( "Number of good lumis: ", len(sig_jet), " Number of bad lumis: ", len(bg_jet)) 

        except OSError:
            print("This Primary Dataset doesn't have ", bg_jets[i])
    return good_jets, bad_jets

# %%
#Load good and bad jets
good_jets, bad_jets = get_jets(bg_files, bg_jets, sig_files, sig_jets)
# Out:
# Number of good lumis:  17238  Number of bad lumis:  492

# %%
#Assign good jets class label 0
df1 = pd.DataFrame(good_jets)
# cutted_df = df1.iloc[0:25000, :]   #Temporarily to make training faster
# df1 = cutted_df                   #Temporarily to make training faster
df1['class'] = 0

#Assign bad_jets class label  1
df2 = pd.DataFrame(bad_jets)
# cutted_df = df2.iloc[0:, :]    #Temporarily to make training faster
# df2 = cutted_df                   #Temporarily to make training faster
df2['class'] = 1

del(good_jets)
del(bad_jets)
#Concatenate them
frames = [df1,df2]
data   = pd.concat(frames)

#Shuffle them randomly
data = shuffle(data)
data = data.reset_index(drop=True)

#Save labels and delete them from df not to cheat during training
# labels = data['class'].astype(int)
# del data['class']

# %% [markdown]
# # Exploration

# %%
print(data.shape)
# Out:
# (17730, 2803)

# %%
data.isnull().values.any()
# Out:
# False

# %%
count_classes = pd.value_counts(data['class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)

plt.title("Good/Bad class distribution for JetC")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency")
# plt.savefig("jetC_StandardScaler_e350_bs1000_ed14_GOODBAD.pdf")
# Out:
# /usr/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
anomalies = data[data['class'] == 1]
normal    = data[data['class'] == 0]

# %%
anomalies.shape
del(anomalies)

# %%
normal.shape
del(normal)

# %% [markdown]
# Let's have a more graphical representation:

# %% [markdown]
# # Autoencoders
#
# Autoencoders can seem quite bizarre at first. The job of those models is to predict the input, given that same input.
#
# More specifically, let’s take a look at Autoencoder Neural Networks. This autoencoder tries to learn to approximate the following identity function:
#
# $$\textstyle f_{W,b}(x) \approx x$$
#
# While trying to do just that might sound trivial at first, it is important to note that we want to learn a compressed representation of the data, thus find structure. This can be done by limiting the number of hidden units in the model. Those kind of autoencoders are called *undercomplete*.
#
# Here's a visual representation of what an Autoencoder might learn:
#
# ![](http://curiousily.com/assets/12.what_to_do_when_data_is_missing_part_ii_files/mushroom_encoder.png)
#
# ## Reconstruction error
#
# We optimize the parameters of our Autoencoder model in such way that a special kind of error - reconstruction error is minimized. In practice, the traditional squared error is often used:
#
# $$\textstyle L(x,x') = ||\, x - x'||^2$$

# %% [markdown]
# # Preparing the data

# %%
data.shape
# Out:
# (17730, 2803)

# %%
from sklearn.preprocessing import StandardScaler

#Normalize the data to make training better
cutted_data = data.iloc[:, 0:2802]
classes     = data.iloc[:, 2802:2803]

# print("Cutted data: ", cutted_data)
# print("Classes : ", classes)
# del(data)

np_scaled = StandardScaler().fit_transform(cutted_data)
datas    = pd.DataFrame(np_scaled)
del(np_scaled)
del(cutted_data)
# print("Datas first: ", datas)
datas['class'] = classes
# data = pd.concat([datas, classes])
print("Datas second: ", datas)

# del(np_scaled)
# print(cutted_data)
# print(classes)
# Out:
# Datas second:                0         1         2         3         4         5         6  \
# 0     -0.537519 -0.993607  0.131890  1.229865  1.221060  1.208023  1.140595
# 1     -0.372823 -0.206962 -0.309462 -0.488090 -0.485138 -0.554297 -0.509775
# 2     -0.476151 -0.825834 -0.088786  1.006821  1.023404  1.015626 -0.506445
# 3     -0.607451 -0.762961 -0.540170  0.600637  0.617362  0.590974 -0.082524
# 4     -0.557226 -0.724374 -0.530139  1.177642  1.181118  1.213438 -0.346023
# 5     -0.633731 -0.565049 -0.359616  0.439867  0.431670  0.351666 -0.346161
# 6     -0.425535 -1.207494 -0.169032  2.103877  2.089252  2.120617  0.200617
# 7     -0.158036  0.129486 -0.610385 -0.247612 -0.218235 -0.299252 -0.041086
# 8     -0.139347 -0.081362  0.202106 -0.398324 -0.436680 -0.573836 -0.868607
# 9     -0.285283  0.023584  0.232198  0.016797  0.015233 -0.081714 -0.346410
# 10    -0.359321 -0.058645  1.114904 -0.601625 -0.617472 -0.723670  0.111183
# 11     0.222117  0.605921 -0.640477 -0.947855 -0.935341 -1.004915  0.364934
# 12    -0.414231 -0.286415 -0.239247 -0.499488 -0.531527 -0.617292 -0.299775
# 13     1.211809  1.608640 -0.590323 -1.199000 -1.199081 -1.103275  0.165351
# 14    -0.490180 -0.643545 -0.610385  0.733220  0.707941  0.659490 -0.022713
# 15     1.944345  1.545398 -0.620416 -1.621409 -1.591374 -1.407957 -0.455269
# 16     0.355761  0.797235  0.874166 -1.014092 -1.040387 -1.100078 -0.170435
# 17     1.289829  1.494860 -0.409770 -1.402464 -1.389460 -1.295122  0.053345
# 18    -0.384839 -0.061068 -0.189093 -0.113315 -0.150573 -0.225654  0.031459
# 19    -0.510349 -0.409840 -0.520108  0.750466  0.729746  0.691087  0.333364
# 20     1.266559  1.542836 -0.540170 -1.222077 -1.202435 -1.184429 -0.613155
# 21    -0.520683 -0.361483 -0.108847  0.163894  0.150342  0.039335 -0.365382
# 22    -0.639003 -0.991754 -0.199124  1.109722  1.096665  1.103643 -0.506692
# 23     0.090951  0.331427  0.141921 -0.936400 -0.932114 -0.974119  0.263270
# 24    -0.493812 -0.264345 -0.048663  0.226841  0.232413  0.182459 -0.170750
# 25    -0.533319 -0.297037  0.131890  0.653758  0.646534  0.543328  1.180205
# 26    -0.581871 -0.555025  1.064750 -0.244322 -0.288240 -0.402591 -0.341484
# 27    -0.588534 -1.076888 -0.319493  1.448162  1.443126  1.458223 -0.380183
# 28    -0.315732 -0.079773 -0.580293 -0.763989 -0.780024 -0.874848  0.103868
# 29    -0.601785 -0.936626 -0.349585  1.113296  1.097319  1.129867 -0.102548
# ...         ...       ...       ...       ...       ...       ...       ...
# 17700 -0.454134 -0.948247 -0.530139  1.218420  1.272995  1.292545 -0.414761
# 17701 -0.462019 -0.753659 -0.148970  1.141196  1.192018  1.193245  0.275304
# 17702 -0.609868 -0.725157 -0.169032  0.532074  0.506831  0.408361 -0.306394
# 17703  0.725721  1.074645 -0.289401 -0.997335 -1.009661 -1.033788 -0.218678
# 17704 -0.382201 -1.280269 -0.620416  2.137077  2.208844  2.312017  0.214565
# 17705 -0.100913  0.263698 -0.530139 -0.169998 -0.185096 -0.284545 -0.036929
# 17706 -0.342687 -0.184544 -0.449893  0.154589  0.159035  0.101837 -0.446297
# 17707 -0.421984 -0.547992 -0.570262  0.793040  0.827671  0.812963 -0.294875
# 17708 -0.304974 -0.137700 -0.058694  0.038233  0.049521 -0.031653 -0.438163
# 17709 -0.442413 -1.042638 -0.580293  1.775162  1.791827  1.860126  0.175410
# 17710 -0.484765 -0.273267  0.041614  0.149647  0.053341 -0.071618 -0.252027
# 17711 -0.351231 -0.137104 -0.419801  0.097623  0.055325  0.014980  0.023720
# 17712 -0.407149 -0.410851 -0.209155  0.512940  0.507395  0.475001 -0.280202
# 17713 -0.355351 -0.295733 -0.379678  0.653454  0.634473  0.615106 -0.025789
# 17714  0.960965  0.536209  0.202106 -1.508375 -1.465736 -1.355019 -0.170155
# 17715  1.142377  1.400363 -0.229216 -1.281227 -1.277148 -1.245148 -0.281417
# 17716  1.444985  1.662014  0.001491 -1.379554 -1.373735 -1.312961 -0.406409
# 17717 -0.789387 -0.743571 -0.459924 -0.300143 -0.323768 -0.461552 -0.264681
# 17718  2.747816  2.051764  0.743766 -1.739609 -1.651245 -1.266963 -0.647048
# 17719  0.635164  1.007458 -0.118878 -1.059321 -1.093930 -1.100329  0.082757
# 17720  7.658933  7.169871  1.094842 -1.675052 -1.512636 -0.673171 -0.391099
# 17721  0.446008  0.452338 -0.640477 -0.441337 -0.446048 -0.356417 -0.344872
# 17722 -0.412432 -0.882295 -0.469954  1.606591  1.663760  1.703067  0.223294
# 17723 -0.480860 -0.327412  0.141921 -0.027996 -0.035139 -0.128476 -0.149885
# 17724 -0.008470  0.134508 -0.118878 -0.816045 -0.808311 -0.863097 -0.440001
# 17725  3.070614  2.239590 -0.590323 -1.683867 -1.646717 -1.269622 -0.356297
# 17726 -0.170900  0.280585  0.783889 -0.255776 -0.305571 -0.393794 -0.219006
# 17727 -0.390976 -0.312837 -0.249278 -0.391818 -0.359548 -0.424777 -0.313633
# 17728 -0.061820  0.504144 -0.209155 -0.841520 -0.833413 -0.914118 -0.044443
# 17729 -0.200039  0.029390 -0.469954 -0.028298 -0.023093 -0.063470  0.218991
#
#                7         8         9  ...        2793      2794       2795  \
# 0       0.257546  1.001834 -0.233888  ...    0.026947  0.771378  -0.682878
# 1       0.136975 -0.300213  0.004128  ...    0.710872 -0.137204  -0.492494
# 2      -0.048457  0.868083 -0.330893  ...    0.463411  0.660971  -0.469648
# 3       0.029910  0.655883 -0.204308  ...   -0.916441 -0.226362  -0.463790
# 4       0.126836  1.009676  0.243853  ...    0.650350  0.641859  -0.604381
# 5       0.145028  0.597807  0.024285  ...   -0.312602 -0.568685   0.467039
# 6       0.237923  1.477852 -0.136630  ...   -0.918821  0.759742  -0.112899
# 7       0.146134  0.087510  0.180138  ...   -1.383145  0.071394  -0.545802
# 8      -1.922829 -0.104251  0.658248  ...    2.293081  0.335511  10.807503
# 9      -0.068052  0.267209 -0.291405  ...   -0.142310 -0.387747   0.375069
# 10      0.160243 -0.356600  0.102260  ...   -0.152679 -0.285974  -0.442116
# 11      0.446557 -0.710186 -0.106409  ...   -2.462450  0.250099  -0.245874
# 12      0.697498 -0.184334  0.188735  ...   -0.770285 -0.474266  -0.369477
# 13      0.015237 -1.241480 -0.059034  ...   -1.524358  0.119049   1.772777
# 14      0.786242  0.691682 -0.093315  ...   -0.539359  0.796936   0.076313
# 15      0.331893 -2.005973  0.123359  ...   -2.631463 -0.599572  -0.133402
# 16     -0.756995 -0.838288  0.280592  ...   -0.483909  0.362843  -0.507139
# 17     -0.352333 -1.484158  0.176185  ...    0.831367  0.318164   0.358081
# 18     -0.264768  0.150255  0.111760  ...    0.524477 -0.334987  -0.163277
# 19     -0.080715  0.705316 -0.066688  ...    0.222885  0.224464  -0.330229
# 20     -0.764707 -1.318880 -0.059267  ...    0.428521 -0.402723   4.349106
# 21     -0.287114  0.370975  0.097393  ...   -0.301580 -0.032161  -0.563961
# 22     -0.009933  0.907507 -0.131618  ...   -1.678834  0.277318  -0.484293
# 23      0.512141 -0.730884  0.131461  ...   -0.555103  0.601143   0.332892
# 24      0.390827  0.442601  0.106320  ...   -0.576499  0.500235   0.199330
# 25      0.037316  0.710311 -0.087962  ...   -1.743793  0.375518  -0.212484
# 26      0.158780 -0.069043  0.133607  ...   -0.186541  0.119256  -0.251732
# 27     -0.317421  1.147646 -0.247128  ...   -0.762403  0.637005  -0.592080
# 28      0.412588 -0.447325 -0.072624  ...    1.472552 -1.099775   1.134260
# 29     -0.202200  0.991857 -0.113442  ...   -0.391632  0.717122   0.148952
# ...          ...       ...       ...  ...         ...       ...        ...
# 17700  -0.233982  1.047204 -0.282089  ...    0.494896  0.311078  -0.455003
# 17701   0.184978  0.954303 -0.363902  ...   -0.203549  0.406414  -0.083023
# 17702  -0.400081  0.626661  0.235101  ...   -0.427740 -0.468971  -0.300939
# 17703  -0.502128 -0.911214 -0.019769  ...    0.084680 -0.795054   1.189325
# 17704   0.447404  1.543584 -0.393200  ...    0.452889  0.500936  -0.560447
# 17705   0.745157  0.052126  0.068688  ...    0.494241  0.180495  -0.609068
# 17706   0.003924  0.331139 -0.165219  ...   -2.233936 -0.623019   0.212804
# 17707   0.384393  0.805096  0.405370  ...   -0.090531 -0.179850   0.414317
# 17708   0.037603  0.236781  0.302808  ...   -0.916528  0.537906  -0.036160
# 17709   0.127230  1.339016 -0.208621  ...    0.652449  0.987036  -0.247046
# 17710  -0.056132  0.363192 -0.321267  ...   -0.597003  0.519166   1.158278
# 17711  -0.518487  0.282443  0.075031  ...    0.826291  0.159860  -0.026787
# 17712   0.408640  0.626784 -0.085767  ...   -0.468947  0.162153  -0.375921
# 17713  -0.061937  0.636202 -0.438477  ...   -0.410345  0.334776  -0.357761
# 17714   0.309227 -1.778814  0.777081  ...   -0.696728  0.100300   2.613394
# 17715  -0.316252 -1.345345  0.363492  ...   -0.761975 -1.394062   0.456495
# 17716   0.367082 -1.567673  0.176534  ...   -0.647372 -0.146877   1.205727
# 17717   0.105872  0.032638  0.054496  ...    0.584684  0.052662  -0.680535
# 17718  -0.889191 -2.499274  0.037399  ...   -1.585519  0.024474   3.302289
# 17719   0.300201 -0.965885  0.081734  ...    0.047830 -0.617594   0.274312
# 17720  -0.939344 -2.994271  0.467113  ...    1.701981 -1.960106   3.842393
# 17721 -33.652138 -2.380673 -0.354197  ...    0.725073  0.046632  -0.619612
# 17722   0.483077  1.185483 -0.331262  ...    0.028679  0.984882  -0.313827
# 17723  -0.080242  0.253474  0.122048  ...    0.464091 -0.251254  -0.416927
# 17724  -0.335275 -0.595017  0.197371  ...    0.703102  0.503489  -0.509482
# 17725  -0.100591 -2.490722  0.288655  ...    0.369568 -1.275729   1.002456
# 17726  -0.896518  0.040707  0.271820  ...   -1.453930  1.028644   0.097988
# 17727  -0.192559 -0.145819  0.232206  ...    0.469932  0.949383  -0.683464
# 17728   0.702170 -0.472152  0.484667  ...    0.255806 -0.042189  -0.296253
# 17729   0.211447  0.159795  0.118910  ...   -0.101472  0.544490  -0.368306
#
#            2796  2797      2798      2799      2800      2801  class
# 0     -0.168419   0.0  0.129288 -0.316567 -0.543725 -0.543725      0
# 1      0.588486   0.0  0.119147  0.520059  0.467463  0.467463      0
# 2     -0.176575   0.0  0.741494 -0.048684 -0.422333 -0.422333      0
# 3     -0.278397   0.0 -0.770352  0.277544 -0.272812 -0.272812      0
# 4      0.301212   0.0  0.386668  0.540860 -0.937096 -0.937096      0
# 5      0.608653   0.0 -0.747188 -0.020780 -0.401750 -0.401750      0
# 6     -1.155859   0.0 -0.171413  0.511434 -1.084031 -1.084031      0
# 7     -0.657857   0.0 -0.646585  0.390176 -0.539252 -0.539251      0
# 8      0.190256   0.0  1.871748 -7.021243  0.421646  0.421646      0
# 9      0.060902   0.0 -0.353876  0.124831 -0.504826 -0.504826      0
# 10    -0.014715   0.0 -0.176253 -0.375927  0.305763  0.305763      0
# 11    -1.836267   0.0 -0.966400 -0.027375  0.377185  0.377185      0
# 12     0.120000   0.0 -0.718216  0.500780  0.597243  0.597243      0
# 13    -0.669874   0.0 -0.837415 -1.352583  0.136555  0.136554      0
# 14    -0.594550   0.0 -0.143341  0.073081 -0.483942 -0.483942      0
# 15    -1.616447   0.0 -1.420154 -1.607781  2.301308  2.301307      0
# 16    -0.560705   0.0  0.143614 -0.182118  0.591313  0.591313      0
# 17     0.493383   0.0  0.468840 -0.261265  0.310529  0.310529      0
# 18     0.418062   0.0 -0.227581 -0.841170 -0.386410 -0.386410      0
# 19     0.452683   0.0 -0.032081 -0.150662 -1.102278 -1.102278      0
# 20    -0.481197   0.0  0.540124  0.237970  0.312095  0.312095      0
# 21     0.050027   0.0 -0.090537  0.554052 -0.457974 -0.457974      0
# 22    -0.574489   0.0 -0.746079  0.338934 -0.942588 -0.942588      0
# 23    -1.213884   0.0 -0.160068  0.436346  0.352422  0.352422      0
# 24    -0.885361   0.0 -0.030793 -0.221184 -0.340649 -0.340649      0
# 25    -1.276253   0.0 -0.844344  0.328787 -0.952360 -0.952360      0
# 26    -0.229992   0.0 -0.184783 -0.185162  0.454993  0.454993      0
# 27    -0.833296   0.0  0.100742  0.195860 -0.963059 -0.963059      0
# 28     1.009821   0.0  0.336473 -0.816817  0.540865  0.540865      0
# 29    -0.467513   0.0 -0.427826 -0.248582 -0.841577 -0.841578      0
# ...         ...   ...       ...       ...       ...       ...    ...
# 17700 -0.112556   0.0  0.792751  0.467294 -0.388636 -0.388637      0
# 17701  0.166604   0.0 -0.169101  0.502302 -0.861565 -0.861565      0
# 17702  0.248025   0.0 -0.601649  0.556081 -0.433286 -0.433286      0
# 17703  0.326634   0.0 -0.378084  0.557096  0.331092  0.331092      0
# 17704  0.045800   0.0  0.438732  0.425184 -1.124867 -1.124867      0
# 17705  0.148404   0.0  0.235106 -0.215096 -0.324986 -0.324986      0
# 17706 -0.786781   0.0 -1.669598  0.013213 -0.514933 -0.514933      0
# 17707  0.306736   0.0 -0.143341  0.518030 -1.027648 -1.027649      0
# 17708 -0.949460   0.0 -0.488158  0.529191 -0.445081 -0.445080      0
# 17709 -0.167207   0.0  0.815933  0.439390 -1.099676 -1.099676      0
# 17710 -0.218943   0.0 -0.049570 -0.727016 -0.583934 -0.583934      0
# 17711  0.301332   0.0  0.152456 -0.330265 -0.466660 -0.466660      0
# 17712 -0.342766   0.0  0.011017  0.059889 -0.329190 -0.329190      0
# 17713 -0.574469   0.0 -0.137811 -0.637214 -0.727019 -0.727019      0
# 17714 -0.486369   0.0  0.213850  0.486066  2.096773  2.096773      0
# 17715  0.367741   0.0 -1.456433  0.448522  0.419469  0.419469      0
# 17716 -0.485847   0.0  0.023396 -0.358677  0.273737  0.273737      0
# 17717  0.565629   0.0  0.121679  0.503316  0.460002  0.460002      0
# 17718 -1.151289   0.0 -0.545937 -1.483480  2.516416  2.516416      0
# 17719  0.193014   0.0 -0.306421 -0.559589  0.434086  0.434086      0
# 17720  3.271782   0.0 -0.617883 -0.713317 -1.488863 -1.488863      0
# 17721  0.531881   0.0  0.083265  0.424677  0.626773  0.626773      0
# 17722 -0.419182   0.0  0.345686  0.436853 -1.083485 -1.083485      0
# 17723  0.442666   0.0 -0.278212 -0.090287 -0.539128 -0.539128      0
# 17724 -0.021258   0.0  1.036396  0.473890  0.428971  0.428971      0
# 17725  0.715523   0.0 -0.385782 -3.357644  2.360218  2.360218      0
# 17726 -0.990514   0.0 -0.628793  0.204485 -0.442663 -0.442663      0
# 17727 -0.407434   0.0  0.940740 -0.293736  0.429508  0.429508      0
# 17728  0.216190   0.0 -0.158794  0.423154  0.518383  0.518382      0
# 17729 -0.418310   0.0  0.536675 -0.148633 -0.373018 -0.373018      0
#
# [17730 rows x 2803 columns]

# %% [markdown]
# Training our Autoencoder is gonna be a bit different from what we are used to. Let's say you have a dataset containing a lot of previously classified lumisections as good. You want to detect any anomaly on new lumisections. We will create this situation by training our model on the normal lumis, only. Reserving the correct class on the test set will give us a way to evaluate the performance of our model. We will reserve 15% of our data for testing:

# %%
X_train, X_test = train_test_split(datas, test_size=0.15, random_state=RANDOM_SEED)
X_train = X_train[X_train['class']== 0]
print(X_train)
X_train = X_train.drop(['class'], axis=1)

y_test = X_test['class']

print("Number of good lumis in X_test: ", len(X_test[X_test['class']==0]))  #try y_test == 0
print("Number of bad lumis in X_test: ",  len(X_test[X_test['class']==1]))  #try y_test == 1

X_test = X_test.drop(['class'], axis=1)


X_train = X_train.values
X_test = X_test.values
# Out:
#               0         1         2         3         4         5         6  \
# 4168  -0.497841 -0.346713 -0.289401 -0.389133 -0.411956 -0.504974 -0.400884
# 10678 -0.462255 -0.899600 -0.620416  1.253296  1.289025  1.298934  0.329735
# 617    1.485302  1.982213  0.503028 -1.311573 -1.312438 -1.245869 -0.346747
# 12441  1.988361  1.428318  0.563213 -1.629902 -1.575295 -1.341126  0.041805
# 4724   1.118555  1.411092  0.743766 -1.286391 -1.253734 -1.229028  0.000282
# 5885  -0.364879 -0.123290 -0.148970  0.339504  0.346376  0.249291 -0.303086
# 9025  -0.126259  0.292729 -0.219186 -0.180624 -0.228001 -0.286405 -0.393358
# 14157  0.694071  1.161790  0.663520 -1.106125 -1.135074 -1.190575 -0.381091
# 9910   0.942400  0.763785  0.533120 -1.416575 -1.449887 -1.378810 -0.308201
# 5046  -0.500376 -0.221369 -0.500047 -0.308086 -0.296112 -0.431902 -0.067859
# 10845 -0.124731  0.097195  1.034658 -0.038815 -0.055833 -0.099787 -0.308688
# 7475  -0.284156  0.038468  0.212136 -0.767446 -0.755234 -0.855687  1.070936
# 177   -0.415561 -0.327621  0.362598  0.164903  0.122496  0.040255 -0.102105
# 15110 -0.178278  0.129937 -0.329524 -0.136017 -0.157687 -0.205856 -0.158252
# 9716  -0.272006 -0.016229 -0.159001 -0.093967 -0.078321 -0.166278 -0.246816
# 12735 -0.328620 -0.030511  0.091768  0.084231  0.069773 -0.026799  0.034817
# 11671  0.842783  1.303184 -0.500047 -1.118216 -1.107336 -1.118457 -0.313365
# 6759  -0.448948 -0.293300 -0.560231 -0.557550 -0.593994 -0.681718 -0.418926
# 4930  -0.094858  0.316730 -0.289401 -0.287839 -0.323374 -0.412836  0.050399
# 5022  -0.598067 -0.615754  0.803951  0.620917  0.618536  0.560462  1.159242
# 11856  0.010890  0.195656  2.418901 -0.880202 -0.895880 -0.959765 -0.290912
# 6178  -0.352702 -0.193792 -0.590323  0.063654  0.051360 -0.008821  0.042811
# 5714  -0.354486 -0.175642 -0.490016  0.145113  0.116433  0.014654 -0.306834
# 1092   1.667910  1.288392 -0.630446 -1.593442 -1.548597 -1.380987 -0.476670
# 13103  0.015861  0.409396 -0.560231 -0.757560 -0.781095 -0.832562  0.495882
# 6211   1.444566  1.735660 -0.389708 -1.269898 -1.265911 -1.161847  0.331859
# 7634  -0.023436  0.230218 -0.469954 -0.875491 -0.904584 -0.972439 -0.593707
# 12826 -0.341894 -0.199719  0.402721  0.661776  0.665561  0.619871  0.628676
# 35    -0.480376 -1.418934 -0.058694  1.825314  1.875208  1.997970  0.736486
# 473    0.993460  0.805115 -0.359616 -1.481268 -1.494386 -1.390178 -0.612265
# ...         ...       ...       ...       ...       ...       ...       ...
# 14502 -0.347284 -1.001572  0.161983  1.948012  1.994255  2.090221  0.152205
# 8838   0.628248  1.185480  0.031583 -1.004820 -1.049966 -1.120802  0.036075
# 3890  -0.497445 -0.406716  0.031583  0.428551  0.404493  0.351424  0.761536
# 3556   1.852439  2.027161 -0.189093 -1.402989 -1.401972 -1.282861 -0.507054
# 11394 -0.497239 -0.521942 -0.239247  0.926465  0.891696  0.865178  0.393675
# 1267   2.771333  1.987395  0.031583 -1.747282 -1.659830 -1.293421 -0.509930
# 1899  -0.354686 -0.236897 -0.449893  0.243003  0.192458  0.112246 -0.389552
# 3005   0.438996  0.843152 -0.169032 -1.002119 -0.995424 -1.040171 -0.484608
# 189   -0.484298 -0.577952  1.104873  0.634193  0.646517  0.605345  0.210701
# 2747   0.872406  1.233563  0.021552 -1.135920 -1.165259 -1.248926 -0.334757
# 8666  -0.541811 -0.760708  1.064750  0.965429  0.977370  0.990670 -0.488364
# 6396   0.779396  1.685369 -0.590323 -1.146761 -1.139843 -1.113562  4.464497
# 17568  1.458214  1.637356  0.803951 -1.304551 -1.304977 -1.235074 -0.433996
# 6420   2.142942  1.703434  0.703643 -1.701363 -1.646195 -1.338432 -0.621752
# 5051  -0.275702  0.230037 -0.319493 -0.198836 -0.224152 -0.342646 -0.143895
# 5311  -0.527171 -0.701041 -0.409770  0.934863  0.975879  0.934229  0.371207
# 2433  -0.594865 -1.070650 -0.048663  1.169796  1.152266  1.138191 -0.218144
# 769   -0.339767 -0.130216  3.472130  0.236726  0.196419  0.157238  0.439374
# 1685  -0.096665  0.194599 -0.289401 -0.255395 -0.274138 -0.345082 -0.388001
# 8322   1.511551  0.994171 -0.359616 -1.588146 -1.551370 -1.351828 -0.643554
# 16023 -0.382861 -0.320225  0.031583 -0.466791 -0.467225 -0.551526 -0.312316
# 11363  1.031884  1.359345 -0.199124 -1.258071 -1.218679 -1.227066 -0.399054
# 14423  1.325610  1.693795 -0.409770 -1.298366 -1.291009 -1.265982 -0.031944
# 4426   1.335312  1.567070 -0.138940 -1.352959 -1.304540 -1.196626 -0.070335
# 16850 -0.255665 -0.005296 -0.339555 -0.509246 -0.526404 -0.567985 -0.276991
# 6265  -0.506524 -0.753244 -0.500047  1.215371  1.179316  1.187712 -0.010465
# 11284 -0.524405 -0.983647 -0.289401  1.114512  1.144014  1.170903 -0.210904
# 11964  0.015594  0.468382 -0.068724 -0.335623 -0.334002 -0.351636 -0.042800
# 5390  -0.177708 -0.149024 -0.359616 -0.768076 -0.775710 -0.826378 -0.604343
# 860   -0.367639 -0.117220 -0.449893 -0.667231 -0.699342 -0.782185 -0.381978
#
#               7         8         9  ...        2793      2794      2795  \
# 4168   0.385162 -0.106919  0.185073  ...    0.421672 -0.172755 -0.565133
# 10678  0.517144  0.998165  0.078888  ...    0.843802  1.210101 -0.594423
# 617    0.261509 -1.331021 -0.061093  ...   -0.507074 -0.317554 -0.487222
# 12441  0.550550 -2.184254  0.408751  ...   -0.374079  0.303672  2.804949
# 4724   0.602878 -1.220960  0.362783  ...    0.300549 -0.337133  0.650393
# 5885  -0.336004  0.502672  0.154668  ...   -1.007543  0.489853 -0.363034
# 9025   0.001699  0.016286 -0.009841  ...    0.172370  0.163892 -0.673505
# 14157  0.451791 -0.992702  0.123272  ...    0.174480 -0.381024  0.320004
# 9910  -0.547189 -1.613533 -0.131588  ...   -0.954207 -0.656467 -0.006284
# 5046   0.164815  0.053991  0.111459  ...   -2.146627 -0.458771 -0.466134
# 10845 -0.408621  0.179569  0.247923  ...   -1.236272 -0.526749 -0.180851
# 7475  -0.118391 -0.458547  0.125554  ...   -0.113531  0.446637 -0.553417
# 177    0.499020  0.371767  0.067396  ...    0.109253  0.541860 -0.045532
# 15110  0.572876  0.039728  0.078489  ...    1.263917  0.253785 -0.215999
# 9716   0.184008  0.100076  0.155969  ...   -0.108787  0.638961 -0.116999
# 12735  0.067398  0.270758  0.211525  ...   -0.203908  0.076473 -0.590908
# 11671 -0.054858 -0.979097 -0.059791  ...   -0.952173  0.828170  0.064011
# 6759   0.380091 -0.301774 -0.039518  ...   -1.501642  0.584678  1.302969
# 4930  -0.577209 -0.032444 -0.046891  ...    0.759452  0.200256 -0.018586
# 5022  -0.391535  0.643987  0.169686  ...   -0.252157  0.892428 -0.170893
# 11856 -0.302311 -0.680235  0.013589  ...   -1.257995  0.186439 -0.517684
# 6178   0.075427  0.252901 -0.303859  ...    0.161511  0.117033 -0.128715
# 5714   0.755578  0.373709 -0.137504  ...   -0.102710  0.147851 -0.678192
# 1092  -1.231539 -2.083810  0.057633  ...   -0.054926  0.272110  0.561352
# 13103 -0.425861 -0.590839 -0.351759  ...   -0.415445  0.778577  0.329963
# 6211  -0.147440 -1.369168 -0.232557  ...    0.915910 -0.343527 -0.015071
# 7634   0.143084 -0.666415  0.104805  ...   -0.535042 -0.231571  0.447122
# 12826  0.188044  0.701378  0.173523  ...   -1.415552  0.566483 -0.534672
# 35    -0.179739  1.296996 -0.356140  ...   -0.382444  1.249060  1.220372
# 473   -0.123973 -1.641023  0.108652  ...    0.281799  0.317014 -0.518855
# ...         ...       ...       ...  ...         ...       ...       ...
# 14502 -0.442771  1.403960 -0.193749  ...    0.425700  0.937764 -0.555760
# 8838   0.119185 -0.934688 -0.037692  ...   -0.508342 -1.960227  1.089740
# 3890   0.560468  0.522829 -0.138087  ...   -0.687901 -0.106698  1.618713
# 3556   0.048279 -1.581260 -0.263166  ...    0.290172  0.457625  3.372585
# 11394 -0.149274  0.842910  0.304469  ...   -0.583506  0.826136 -0.660032
# 1267   0.719601 -2.410642 -0.163762  ...    0.488832  0.254157 -0.456761
# 1899  -0.000609  0.323730 -0.180363  ...   -0.202756  0.347373 -0.339016
# 3005   0.023465 -0.802063  0.021215  ...   -0.592195  0.560678 -0.406382
# 189    0.244513  0.671640  0.474020  ...   -0.105737 -0.331509  0.047023
# 2747   0.501799 -1.161226 -0.067903  ...    0.699078 -0.663155 -0.604381
# 8666   0.324298  0.899824  0.100473  ...   -0.026299  0.603124 -0.073065
# 6396  -0.233045 -1.041182  0.307452  ...   -0.948581 -0.260624  0.358667
# 17568  0.843281 -1.446768  0.439972  ...   -0.345593 -0.322425  2.349200
# 6420   0.178989 -2.157324  0.058857  ...    1.595402 -0.602047 -0.464376
# 5051  -0.293103  0.139434  0.055856  ...    0.292692  0.031110 -0.167378
# 5311  -0.041782  0.943548 -0.038420  ...   -0.186075  1.204408 -0.364205
# 2433   0.306086  1.000598 -0.168832  ...   -0.107443  0.284050 -0.578021
# 769    0.341645  0.441959  0.056846  ...   -1.967389 -0.087681 -0.423370
# 1685  -0.528024  0.020308 -0.178615  ...    0.942744  0.287251  0.553151
# 8322   0.693784 -1.921008  0.072933  ...    1.259558 -0.882127  0.030035
# 16023 -0.248561 -0.218255  0.035835  ...   -1.139606  0.246717 -0.685221
# 11363 -0.162083 -1.175470  0.089632  ...    1.901026 -0.418877  0.284271
# 14423 -0.542020 -1.352734 -0.141691  ...   -2.442180 -1.750167 -0.005698
# 4426   0.775134 -1.411033 -0.172563  ...   -1.981776 -0.920265  0.623446
# 16850 -0.086694 -0.324248  0.174854  ...   -1.976304 -0.002952 -0.518269
# 6265  -0.077667  0.981838 -0.193254  ...   -0.205359  0.449622 -0.431572
# 11284  0.117619  0.966319  0.357052  ...   -0.497136  0.726034 -0.400524
# 11964  0.733954 -0.004354  0.280981  ...    0.545339  0.243593 -0.400524
# 5390   0.368495 -0.496471 -0.286140  ...   -2.412681  0.106711  0.000746
# 860    0.820714 -0.381596  0.367514  ...   -0.200186 -0.301712 -0.132816
#
#            2796  2797      2798      2799      2800      2801  class
# 4168   0.362180   0.0  0.406344  0.567750  0.419986  0.419986      0
# 10678 -0.285023   0.0  1.413232  0.305448 -0.738751 -0.738751      0
# 617   -0.174479   0.0 -0.866974  0.052786  0.415273  0.415273      0
# 12441 -0.909153   0.0 -0.166987 -0.164868  2.515952  2.515952      0
# 4724   0.294922   0.0  0.042053  0.257250  0.458181  0.458181      0
# 5885  -0.707167   0.0 -0.315621  0.577390 -0.420989 -0.420989      0
# 9025   0.231735   0.0 -0.004215  0.259279 -0.529187 -0.529187      0
# 14157  0.217578   0.0 -0.135375  0.556588  0.275368  0.275368      0
# 9910  -0.275834   0.0 -1.191969 -0.229302  2.594951  2.594951      0
# 5046  -0.673292   0.0 -1.669598 -0.716869  0.228851  0.228851      0
# 10845 -0.425132   0.0 -1.012636  0.333860 -0.458845 -0.458845      0
# 7475  -0.399410   0.0  0.022635  0.401846  0.352422  0.352422      0
# 177   -0.116926   0.0 -0.133512  0.323713 -0.529033 -0.529033      0
# 15110  0.482781   0.0  1.289668 -0.706722 -0.425526 -0.425526      0
# 9716  -0.767037   0.0  0.044149  0.134470 -0.379757 -0.379757      0
# 12735 -0.010928   0.0  0.112703  0.375971 -0.471716 -0.471716      0
# 11671 -1.151369   0.0 -0.204566 -0.593582  0.536224  0.536224      0
# 6759  -1.891068   0.0 -0.204909  0.512956  0.416334  0.416334      0
# 4930   0.363275   0.0  1.040645  0.386118 -0.622255 -0.622255      0
# 5022  -0.756327   0.0 -0.060380 -0.606773 -0.326338 -0.326338      0
# 11856 -0.890450   0.0 -0.440467  0.286676  0.450676  0.450675      0
# 6178   0.142726   0.0 -0.204566  0.096419 -0.437599 -0.437599      0
# 5714   0.042862   0.0 -0.232900 -0.410427 -0.427392 -0.427393      0
# 1092   0.180105   0.0  0.578237 -0.512913  2.397257  2.397257      0
# 13103 -0.849237   0.0  0.273945  0.481500  0.292932  0.292932      0
# 6211   0.586625   0.0  0.590928  0.139544  0.447285  0.447285      0
# 7634  -0.547303   0.0 -0.820479 -0.453552  0.632641  0.632641      0
# 12826 -0.991332   0.0 -0.407523  0.555574 -0.515843 -0.515843      0
# 35    -1.303369   0.0  0.335729  0.108595 -0.610091 -0.610091      0
# 473    0.098075   0.0 -0.143341  0.578912  2.220017  2.220017      0
# ...         ...   ...       ...       ...       ...       ...    ...
# 14502 -0.144714   0.0  0.906462  0.182669 -1.157933 -1.157933      0
# 8838   0.767042   0.0 -1.060459 -0.323162  0.460893  0.460893      0
# 3890  -0.134853   0.0 -0.521173  0.403368 -0.470666 -0.470666      0
# 3556   0.197960   0.0  0.486254  0.265875  0.401135  0.401135      0
# 11394 -0.436646   0.0 -0.003748  0.569780 -0.537291 -0.537291      0
# 1267   0.390554   0.0  0.727522  0.404890  2.241628  2.241628      0
# 1899  -0.189395   0.0 -0.020935  0.269934 -0.388924 -0.388924      0
# 3005  -0.419967   0.0  0.548519  0.502809  0.597639  0.597640      0
# 189    0.248588   0.0 -0.272854 -1.265318 -0.375388 -0.375388      0
# 2747   1.038967   0.0  0.250760  0.336904  0.356954  0.356954      0
# 8666  -0.745964   0.0  0.332132  0.473890 -0.979489 -0.979489      0
# 6396  -0.592350   0.0 -0.814414 -0.068471  0.325703  0.325704      0
# 17568  0.286539   0.0  0.138604  0.487588  0.421422  0.421422      0
# 6420   0.490175   0.0  0.074087  0.227823  2.308344  2.308344      0
# 5051   0.344382   0.0  0.112703  0.568765 -0.459141 -0.459140      0
# 5311  -0.711730   0.0  0.589600 -0.072530 -0.530098 -0.530098      0
# 2433   0.129940   0.0 -0.143341  0.489618 -0.622721 -0.622721      0
# 769   -0.676134   0.0 -1.257676  0.068007 -0.270046 -0.270046      0
# 1685   0.388397   0.0  0.553572  0.422140 -0.183798 -0.183798      0
# 8322   0.896279   0.0  0.035180 -1.985760  2.426262  2.426262      0
# 16023 -1.299692   0.0 -0.226558  0.325235  0.542788  0.542788      0
# 11363  0.377934   0.0  1.052645 -0.668163  0.471183  0.471183      0
# 14423  0.026721   0.0 -2.928438  0.445985  0.569983  0.569983      0
# 4426   0.142723   0.0 -2.129825  0.539338  0.408555  0.408555      0
# 16850 -1.161623   0.0 -0.603394 -0.114640  0.346904  0.346904      0
# 6265  -0.386777   0.0  0.180524 -0.988303 -0.884313 -0.884313      0
# 11284 -0.254459   0.0  0.088732  0.505346 -0.407649 -0.407649      0
# 11964  0.195567   0.0  0.556727  0.288706 -0.402320 -0.402320      0
# 5390  -2.011103   0.0 -0.903303  0.496721  0.465665  0.465666      0
# 860   -0.128454   0.0 -0.477999 -0.195309  0.301279  0.301278      0
#
# [14645 rows x 2803 columns]
# Number of good lumis in X_test:  2593
# Number of bad lumis in X_test:  67

# %%
X_train.shape
# Out:
# (14645, 2802)

# %% [markdown]
# # Building the model
#
# Our Autoencoder uses 7 fully connected layers with 2000, 1000, 500, 500, 1000, 2000 and 2802  neurons respectively.  The first two layers are used for our encoder, the last two go for the decoder. Additionally, L1 regularization will be used during training:

# %%
input_dim = X_train.shape[1]
encoding_dim = 500

# %%
input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="relu" ,
                activity_regularizer=regularizers.l1(10e-5)
               )(input_layer)


encoder = Dense(int(encoding_dim / 1.5), activation="relu")(encoder)

decoder = Dense(input_dim, activation='sigmoid')(encoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)

# %% [markdown]
# Let's train our model for 100 epochs with a batch size of 32 samples and save the best performing model to a file. The ModelCheckpoint provided by Keras is really handy for such tasks. Additionally,  the training progress will be exported in a format that TensorBoard understands.

# %%
nb_epoch = 200
batch_size = 1000
from keras.optimizers import Adam

adam = Adam(lr = 0.00015, beta_1 = 0.9, beta_2 = 0.999, epsilon=1e-08, decay = 0.0)
autoencoder.compile(optimizer=adam, 
                    loss='mean_squared_error', 
                    #metrics=['accuracy']
                   )

checkpointer = ModelCheckpoint(filepath="st_model5_deep1.h5",
                               verbose=0,
                               save_best_only=True)
# tensorboard = TensorBoard(log_dir='./logs',
#                           histogram_freq=0,
#                           write_graph=True,
#                           write_images=True)

history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=2,
                    callbacks=[checkpointer
#                               ,tensorboard
                              ]).history
# Out:
# Train on 14645 samples, validate on 2660 samples
# Epoch 1/200
# 10s - loss: 17.8396 - val_loss: 16.3626
# Epoch 2/200
# 9s - loss: 15.0505 - val_loss: 15.1991
# Epoch 3/200
# 9s - loss: 13.4162 - val_loss: 14.5814
# Epoch 4/200
# 10s - loss: 12.1856 - val_loss: 14.1522
# Epoch 5/200
# 9s - loss: 11.1751 - val_loss: 13.8192
# Epoch 6/200
# 9s - loss: 10.2761 - val_loss: 13.5628
# Epoch 7/200
# 10s - loss: 9.4835 - val_loss: 13.3174
# Epoch 8/200
# 9s - loss: 8.7606 - val_loss: 13.1026
# Epoch 9/200
# 9s - loss: 8.1079 - val_loss: 12.8687
# Epoch 10/200
# 9s - loss: 7.5026 - val_loss: 12.6883
# Epoch 11/200
# 10s - loss: 6.9535 - val_loss: 12.4727
# Epoch 12/200
# 10s - loss: 6.4455 - val_loss: 12.3467
# Epoch 13/200
# 9s - loss: 5.9790 - val_loss: 12.1589
# Epoch 14/200
# 9s - loss: 5.5438 - val_loss: 12.0330
# Epoch 15/200
# 10s - loss: 5.1509 - val_loss: 11.8567
# Epoch 16/200
# 9s - loss: 4.8005 - val_loss: 11.7572
# Epoch 17/200
# 10s - loss: 4.4722 - val_loss: 11.6215
# Epoch 18/200
# 10s - loss: 4.1741 - val_loss: 11.4525
# Epoch 19/200
# 10s - loss: 3.8919 - val_loss: 11.3424
# Epoch 20/200
# 9s - loss: 3.6326 - val_loss: 11.2202
# Epoch 21/200
# 9s - loss: 3.4056 - val_loss: 11.1057
# Epoch 22/200
# 10s - loss: 3.1876 - val_loss: 10.9901
# Epoch 23/200
# 9s - loss: 3.0009 - val_loss: 10.9044
# Epoch 24/200
# 9s - loss: 2.8206 - val_loss: 10.7981
# Epoch 25/200
# 9s - loss: 2.6657 - val_loss: 10.7506
# Epoch 26/200
# 10s - loss: 2.5296 - val_loss: 10.6057
# Epoch 27/200
# 9s - loss: 2.3901 - val_loss: 10.5403
# Epoch 28/200
# 9s - loss: 2.2661 - val_loss: 10.4843
# Epoch 29/200
# 9s - loss: 2.1562 - val_loss: 10.4000
# Epoch 30/200
# 9s - loss: 2.0589 - val_loss: 10.3356
# Epoch 31/200
# 9s - loss: 1.9621 - val_loss: 10.2676
# Epoch 32/200
# 9s - loss: 1.8799 - val_loss: 10.2182
# Epoch 33/200
# 9s - loss: 1.8035 - val_loss: 10.1656
# Epoch 34/200
# 9s - loss: 1.7311 - val_loss: 10.0957
# Epoch 35/200
# 9s - loss: 1.6641 - val_loss: 10.0557
# Epoch 36/200
# 9s - loss: 1.6059 - val_loss: 10.0119
# Epoch 37/200
# 9s - loss: 1.5503 - val_loss: 9.9618
# Epoch 38/200
# 9s - loss: 1.5036 - val_loss: 9.9352
# Epoch 39/200
# 9s - loss: 1.4536 - val_loss: 9.9003
# Epoch 40/200
# 9s - loss: 1.4128 - val_loss: 9.8515
# Epoch 41/200
# 9s - loss: 1.3737 - val_loss: 9.8295
# Epoch 42/200
# 10s - loss: 1.3335 - val_loss: 9.8006
# Epoch 43/200
# 9s - loss: 1.3026 - val_loss: 9.7654
# Epoch 44/200
# 9s - loss: 1.2706 - val_loss: 9.7521
# Epoch 45/200
# 10s - loss: 1.2397 - val_loss: 9.7294
# Epoch 46/200
# 10s - loss: 1.2134 - val_loss: 9.6880
# Epoch 47/200
# 9s - loss: 1.1885 - val_loss: 9.6677
# Epoch 48/200
# 9s - loss: 1.1679 - val_loss: 9.6623
# Epoch 49/200
# 9s - loss: 1.1454 - val_loss: 9.6266
# Epoch 50/200
# 9s - loss: 1.1256 - val_loss: 9.6119
# Epoch 51/200
# 9s - loss: 1.1072 - val_loss: 9.5833
# Epoch 52/200
# 10s - loss: 1.0862 - val_loss: 9.5820
# Epoch 53/200
# 12s - loss: 1.0759 - val_loss: 9.5703
# Epoch 54/200
# 10s - loss: 1.0544 - val_loss: 9.5447
# Epoch 55/200
# 9s - loss: 1.0404 - val_loss: 9.5290
# Epoch 56/200
# 10s - loss: 1.0274 - val_loss: 9.5231
# Epoch 57/200
# 11s - loss: 1.0128 - val_loss: 9.5000
# Epoch 58/200
# 10s - loss: 1.0014 - val_loss: 9.4995
# Epoch 59/200
# 9s - loss: 0.9926 - val_loss: 9.4814
# Epoch 60/200
# 9s - loss: 0.9793 - val_loss: 9.4600
# Epoch 61/200
# 9s - loss: 0.9710 - val_loss: 9.4593
# Epoch 62/200
# 9s - loss: 0.9615 - val_loss: 9.4512
# Epoch 63/200
# 10s - loss: 0.9510 - val_loss: 9.4207
# Epoch 64/200
# 9s - loss: 0.9418 - val_loss: 9.4293
# Epoch 65/200
# 11s - loss: 0.9348 - val_loss: 9.4018
# Epoch 66/200
# 9s - loss: 0.9276 - val_loss: 9.4130
# Epoch 67/200
# 10s - loss: 0.9214 - val_loss: 9.3960
# Epoch 68/200
# 9s - loss: 0.9142 - val_loss: 9.3784
# Epoch 69/200
# 10s - loss: 0.9064 - val_loss: 9.3704
# Epoch 70/200
# 9s - loss: 0.9025 - val_loss: 9.3725
# Epoch 71/200
# 9s - loss: 0.8964 - val_loss: 9.3494
# Epoch 72/200
# 9s - loss: 0.8897 - val_loss: 9.3507
# Epoch 73/200
# 10s - loss: 0.8848 - val_loss: 9.3455
# Epoch 74/200
# 10s - loss: 0.8787 - val_loss: 9.3253
# Epoch 75/200
# 10s - loss: 0.8726 - val_loss: 9.3246
# Epoch 76/200
# 10s - loss: 0.8683 - val_loss: 9.3187
# Epoch 77/200
# 10s - loss: 0.8637 - val_loss: 9.3100
# Epoch 78/200
# 9s - loss: 0.8598 - val_loss: 9.3018
# Epoch 79/200
# 9s - loss: 0.8556 - val_loss: 9.2900
# Epoch 80/200
# 9s - loss: 0.8516 - val_loss: 9.2820
# Epoch 81/200
# 10s - loss: 0.8473 - val_loss: 9.2753
# Epoch 82/200
# 9s - loss: 0.8442 - val_loss: 9.2633
# Epoch 83/200
# 9s - loss: 0.8393 - val_loss: 9.2604
# Epoch 84/200
# 10s - loss: 0.8352 - val_loss: 9.2544
# Epoch 85/200
# 11s - loss: 0.8337 - val_loss: 9.2459
# Epoch 86/200
# 9s - loss: 0.8299 - val_loss: 9.2395
# Epoch 87/200
# 10s - loss: 0.8274 - val_loss: 9.2282
# Epoch 88/200
# 9s - loss: 0.8242 - val_loss: 9.2289
# Epoch 89/200
# 9s - loss: 0.8221 - val_loss: 9.2172
# Epoch 90/200
# 9s - loss: 0.8193 - val_loss: 9.2157
# Epoch 91/200
# 9s - loss: 0.8163 - val_loss: 9.2065
# Epoch 92/200
# 9s - loss: 0.8140 - val_loss: 9.2022
# Epoch 93/200
# 9s - loss: 0.8118 - val_loss: 9.1956
# Epoch 94/200
# 9s - loss: 0.8101 - val_loss: 9.1914
# Epoch 95/200
# 11s - loss: 0.8074 - val_loss: 9.1820
# Epoch 96/200
# 10s - loss: 0.8053 - val_loss: 9.1780
# Epoch 97/200
# 10s - loss: 0.8033 - val_loss: 9.1733
# Epoch 98/200
# 9s - loss: 0.8013 - val_loss: 9.1623
# Epoch 99/200
# 9s - loss: 0.7989 - val_loss: 9.1670
# Epoch 100/200
# 9s - loss: 0.7977 - val_loss: 9.1564
# Epoch 101/200
# 9s - loss: 0.7949 - val_loss: 9.1470
# Epoch 102/200
# 9s - loss: 0.7947 - val_loss: 9.1457
# Epoch 103/200
# 9s - loss: 0.7931 - val_loss: 9.1399
# Epoch 104/200
# 10s - loss: 0.7914 - val_loss: 9.1305
# Epoch 105/200
# 9s - loss: 0.7898 - val_loss: 9.1312
# Epoch 106/200
# 9s - loss: 0.7884 - val_loss: 9.1256
# Epoch 107/200
# 9s - loss: 0.7869 - val_loss: 9.1236
# Epoch 108/200
# 10s - loss: 0.7856 - val_loss: 9.1155
# Epoch 109/200
# 9s - loss: 0.7843 - val_loss: 9.1072
# Epoch 110/200
# 9s - loss: 0.7833 - val_loss: 9.1094
# Epoch 111/200
# 10s - loss: 0.7809 - val_loss: 9.1033
# Epoch 112/200
# 9s - loss: 0.7808 - val_loss: 9.0971
# Epoch 113/200
# 10s - loss: 0.7798 - val_loss: 9.0926
# Epoch 114/200
# 9s - loss: 0.7756 - val_loss: 9.0925
# Epoch 115/200
# 9s - loss: 0.7745 - val_loss: 9.0898
# Epoch 116/200
# 9s - loss: 0.7768 - val_loss: 9.0832
# Epoch 117/200
# 9s - loss: 0.7759 - val_loss: 9.0756
# Epoch 118/200
# 9s - loss: 0.7751 - val_loss: 9.0687
# Epoch 119/200
# 10s - loss: 0.7743 - val_loss: 9.0685
# Epoch 120/200
# 9s - loss: 0.7734 - val_loss: 9.0629
# Epoch 121/200
# 10s - loss: 0.7726 - val_loss: 9.0621
# Epoch 122/200
# 10s - loss: 0.7719 - val_loss: 9.0534
# Epoch 123/200
# 9s - loss: 0.7713 - val_loss: 9.0508
# Epoch 124/200
# 10s - loss: 0.7698 - val_loss: 9.0460
# Epoch 125/200
# 9s - loss: 0.7699 - val_loss: 9.0411
# Epoch 126/200
# 9s - loss: 0.7691 - val_loss: 9.0374
# Epoch 127/200
# 9s - loss: 0.7684 - val_loss: 9.0382
# Epoch 128/200
# 9s - loss: 0.7677 - val_loss: 9.0307
# Epoch 129/200
# 11s - loss: 0.7672 - val_loss: 9.0279
# Epoch 130/200
# 10s - loss: 0.7667 - val_loss: 9.0229
# Epoch 131/200
# 9s - loss: 0.7648 - val_loss: 9.0247
# Epoch 132/200
# 9s - loss: 0.7655 - val_loss: 9.0149
# Epoch 133/200
# 9s - loss: 0.7632 - val_loss: 9.0138
# Epoch 134/200
# 9s - loss: 0.7639 - val_loss: 9.0086
# Epoch 135/200
# 9s - loss: 0.7639 - val_loss: 9.0033
# Epoch 136/200
# 9s - loss: 0.7619 - val_loss: 9.0047
# Epoch 137/200
# 10s - loss: 0.7614 - val_loss: 9.0024
# Epoch 138/200
# 10s - loss: 0.7623 - val_loss: 8.9931
# Epoch 139/200
# 9s - loss: 0.7618 - val_loss: 8.9890
# Epoch 140/200
# 9s - loss: 0.7610 - val_loss: 8.9881
# Epoch 141/200
# 10s - loss: 0.7610 - val_loss: 8.9826
# Epoch 142/200
# 9s - loss: 0.7606 - val_loss: 8.9785
# Epoch 143/200
# 10s - loss: 0.7603 - val_loss: 8.9781
# Epoch 144/200
# 9s - loss: 0.7597 - val_loss: 8.9741
# Epoch 145/200
# 9s - loss: 0.7590 - val_loss: 8.9732
# Epoch 146/200
# 9s - loss: 0.7579 - val_loss: 8.9735
# Epoch 147/200
# 9s - loss: 0.7586 - val_loss: 8.9668
# Epoch 148/200
# 9s - loss: 0.7580 - val_loss: 8.9655
# Epoch 149/200
# 9s - loss: 0.7579 - val_loss: 8.9641
# Epoch 150/200
# 9s - loss: 0.7578 - val_loss: 8.9624
# Epoch 151/200
# 10s - loss: 0.7573 - val_loss: 8.9565
# Epoch 152/200
# 9s - loss: 0.7564 - val_loss: 8.9573
# Epoch 153/200
# 9s - loss: 0.7565 - val_loss: 8.9545
# Epoch 154/200
# 9s - loss: 0.7561 - val_loss: 8.9525
# Epoch 155/200
# 9s - loss: 0.7560 - val_loss: 8.9512
# Epoch 156/200
# 9s - loss: 0.7555 - val_loss: 8.9488
# Epoch 157/200
# 9s - loss: 0.7553 - val_loss: 8.9438
# Epoch 158/200
# 8s - loss: 0.7550 - val_loss: 8.9490
# Epoch 159/200
# 9s - loss: 0.7543 - val_loss: 8.9456
# Epoch 160/200
# 11s - loss: 0.7542 - val_loss: 8.9413
# Epoch 161/200
# 11s - loss: 0.7542 - val_loss: 8.9410
# Epoch 162/200
# 11s - loss: 0.7539 - val_loss: 8.9398
# Epoch 163/200
# 9s - loss: 0.7537 - val_loss: 8.9398
# Epoch 164/200
# 9s - loss: 0.7535 - val_loss: 8.9382
# Epoch 165/200
# 9s - loss: 0.7534 - val_loss: 8.9406
# Epoch 166/200
# 9s - loss: 0.7533 - val_loss: 8.9394
# Epoch 167/200
# 9s - loss: 0.7530 - val_loss: 8.9368
# Epoch 168/200
# 9s - loss: 0.7527 - val_loss: 8.9357
# Epoch 169/200
# 9s - loss: 0.7527 - val_loss: 8.9368
# Epoch 170/200
# 9s - loss: 0.7524 - val_loss: 8.9370
# Epoch 171/200
# 9s - loss: 0.7523 - val_loss: 8.9376
# Epoch 172/200
# 9s - loss: 0.7522 - val_loss: 8.9375
# Epoch 173/200
# 9s - loss: 0.7521 - val_loss: 8.9369
# Epoch 174/200
# 9s - loss: 0.7520 - val_loss: 8.9392
# Epoch 175/200
# 9s - loss: 0.7519 - val_loss: 8.9392
# Epoch 176/200
# 8s - loss: 0.7518 - val_loss: 8.9371
# Epoch 177/200
# 9s - loss: 0.7516 - val_loss: 8.9376
# Epoch 178/200
# 8s - loss: 0.7516 - val_loss: 8.9389
# Epoch 179/200
# 9s - loss: 0.7515 - val_loss: 8.9410
# Epoch 180/200
# 9s - loss: 0.7515 - val_loss: 8.9408
# Epoch 181/200
# 9s - loss: 0.7514 - val_loss: 8.9412
# Epoch 182/200
# 9s - loss: 0.7513 - val_loss: 8.9405
# Epoch 183/200
# 8s - loss: 0.7513 - val_loss: 8.9384
# Epoch 184/200
# 8s - loss: 0.7512 - val_loss: 8.9408
# Epoch 185/200
# 8s - loss: 0.7512 - val_loss: 8.9426
# Epoch 186/200
# 9s - loss: 0.7511 - val_loss: 8.9436
# Epoch 187/200
# 9s - loss: 0.7511 - val_loss: 8.9431
# Epoch 188/200
# 9s - loss: 0.7510 - val_loss: 8.9437
# Epoch 189/200
# 9s - loss: 0.7510 - val_loss: 8.9458
# Epoch 190/200
# 9s - loss: 0.7510 - val_loss: 8.9458
# Epoch 191/200
# 9s - loss: 0.7510 - val_loss: 8.9467
# Epoch 192/200
# 9s - loss: 0.7509 - val_loss: 8.9467
# Epoch 193/200
# 9s - loss: 0.7509 - val_loss: 8.9465
# Epoch 194/200
# 9s - loss: 0.7509 - val_loss: 8.9478
# Epoch 195/200
# 9s - loss: 0.7509 - val_loss: 8.9477
# Epoch 196/200
# 9s - loss: 0.7508 - val_loss: 8.9492
# Epoch 197/200
# 9s - loss: 0.7508 - val_loss: 8.9494
# Epoch 198/200
# 9s - loss: 0.7508 - val_loss: 8.9492
# Epoch 199/200
# 8s - loss: 0.7508 - val_loss: 8.9498
# Epoch 200/200
# 9s - loss: 0.7508 - val_loss: 8.9513

# %%
autoencoder = load_model('st_model5_deep1.h5')

# %% [markdown]
# # Evaluation

# %%
f = plt.figure()
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
# f.savefig("jetC_MinMaxScaler_e350_bs1000_ed14_LOSS.pdf")
# Out:
# /usr/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# The reconstruction error on our training and test data seems to converge nicely. Is it low enough? Let's have a closer look at the error distribution:

# %%
predictions = autoencoder.predict(X_test)

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()
# print(error_df['reconstruction_error'])
print(predictions.shape)
print(mse.shape)

# print(error_df)
#MSE = mean squared error
# Out:
# (2660, 2802)
# (2660,)

# %% [markdown]
# ## Reconstruction error without anomaly

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=50)
# fig.savefig("jetC_MinMaxScaler_e350_bs1000_ed14_RECERR.pdf")
# Out:
# /usr/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Reconstruction error of anomalous lumis

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
anomaly_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(anomaly_error_df.reconstruction_error.values, bins=50)
# fig.savefig("jetC_MinMaxScaler_e350_bs1000_ed14_RECERRANOMALY.pdf")
# Out:
# /usr/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %% [markdown]
# ROC curves are very useful tool for understanding the performance of binary classifiers. However, our case is a bit out of the ordinary. We have a very imbalanced dataset. Nonetheless, let's have a look at our ROC curve:

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)


plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# plt.savefig("jetC_MinMaxScaler_e350_bs1000_ed14_ROC.pdf")
# Out:
# /usr/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# The ROC curve plots the true positive rate versus the false positive rate, over different threshold values. Basically, we want the blue line to be as close as possible to the upper left corner. While our results look pretty good, we have to keep in mind of the nature of our dataset. ROC doesn't look very useful for us. Onward...
#
# ## Precision vs Recall
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/26/Precisionrecall.svg/350px-Precisionrecall.svg.png" />
#
# Precision and recall are defined as follows:
#
# $$\text{Precision} = \frac{\text{true positives}}{\text{true positives} + \text{false positives}}$$
#
# $$\text{Recall} = \frac{\text{true positives}}{\text{true positives} + \text{false negatives}}$$
#
# Let's take an example from Information Retrieval in order to better understand what precision and recall are. Precision measures the relevancy of obtained results. Recall, on the other hand, measures how many relevant results are returned. Both values can take values between 0 and 1. You would love to have a system with both values being equal to 1.
#
# Let's return to our example from Information Retrieval. High recall but low precision means many results, most of which has low or no relevancy. When precision is high but recall is low we have the opposite - few returned results with very high relevancy. Ideally, you would want high precision and high recall - many results with that are highly relevant.

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# plt.savefig("jetC_MinMaxScaler_e350_bs1000_ed14__RECPRE.pdf")
# Out:
# /usr/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# A high area under the curve represents both high recall and high precision, where high precision relates to a low false positive rate, and high recall relates to a low false negative rate. High scores for both show that the classifier is returning accurate results (high precision), as well as returning a majority of all positive results (high recall).

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()
# plt.savefig("jetC_MinMaxScaler_e350_bs1000_ed14_PRETRE.pdf")
# Out:
# /usr/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# You can see that as the reconstruction error increases our precision rises as well. Let's have a look at the recall:

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Treshold')
plt.ylabel('Recall')
plt.show()
# plt.savefig("jetC_MinMaxScaler_e350_bs1000_ed14_RECTRE.pdf")
# Out:
# /usr/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Here, we have the exact opposite situation. As the reconstruction error increases the recall decreases.

# %% [markdown]
# # Prediction
#
# Our model is a bit different this time. It doesn't know how to predict new values. But we don't need that. In order to predict whether or not a new/unseen lumisection is normal or anomalous, we'll calculate the reconstruction error from the lumisection itself. If the error is larger than a predefined threshold, we'll mark it as a anomaly (since our model should have a low error on normal transactions). Let's pick that value:

# %%
threshold = 33

# %% [markdown]
# And see how well we're dividing the two types of transactions:

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Anomaly" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show()
# fig.savefig("HP6_RECON.pdf")
# Out:
# /usr/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# I know, that chart might be a bit deceiving. Let's have a look at the confusion matrix:

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# plt.savefig("jetC_MinMaxScaler_e350_bs1000_ed14_CONFMAX.pdf")
# Out:
# /usr/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
